# %% [markdown]
# #### Задача 1. ####
#
# 1. Возьмите любой достаточно длинный текст.
# 2. Токенизируйте его несколькими токенизаторами: для каждого токенизатора должно получиться множество токенов (нас интересуют только уникальные).
# 3. Попарно сравните токенизаторы: посчитайте, сколько токенов не совпало (т.е., сколько токенов токенизатор А выдал таких, каких не выдал токенизатор Б, и наоборот).
# 4. Проанализируйте, что это за токены.

# %%
# import nltk
# nltk.download()

from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

text = '''Эндоним Грузии («Сакартвело» — «страна картвелов») восходит к названию Картли (груз. ) — 
одной из основных историко-географических областей Грузии и колыбели картвельской государственности[33]. 
Название Грузии на английском языке — «Georgia», видимо, происходит от Св. Георгия, в связи с популярностью святого в этих краях[34],
а также связано с тем, что Святой Георгий является покровителем Грузии — в средние века на территории Грузии было 365 храмов Святого Георгия. 
Устоявшееся в русском и ряде других языков название «Грузия», скорее всего, происходит от «Гурджан», или «Гурзан» из арабо-персидских источников. 
Считается, что эти названия происходят от арабо-персидского гурдж (Гурджистан — «страна волков»), 
восходящего к персидскому слову горг «волк» и связанному с древнеперсидским Вркан[35]. 
Наименование Грузии на армянском языке — «» (Врастан), в древности — «» (Вирк), означающее в переводе «Верхняя страна».'''

sents_nltk = sent_tokenize(raw)
print(sents_nltk)
tokens_nltk = word_tokenize(text)

from razdel import sentenize
from razdel import tokenize

sents_razdel = [s.text for s in sentenize(text)]
print(sents_razdel)

tokens_razdel = [t.text for t in tokenize(text)]

print(tokens_nltk)
print(tokens_razdel)
# Out:
# ['Эндоним Грузии («Сакартвело» — «страна картвелов») восходит к названию Картли (груз. )', '— \nодной из основных историко-географических областей Грузии и колыбели картвельской государственности[33].', 'Название Грузии на английском языке — «Georgia», видимо, происходит от Св.', 'Георгия, в связи с популярностью святого в этих краях[34],\nа также связано с тем, что Святой Георгий является покровителем Грузии — в средние века на территории Грузии было 365 храмов Святого Георгия.', 'Устоявшееся в русском и ряде других языков название «Грузия», скорее всего, происходит от «Гурджан», или «Гурзан» из арабо-персидских источников.', 'Считается, что эти названия происходят от арабо-персидского гурдж (Гурджистан — «страна волков»), \nвосходящего к персидскому слову горг «волк» и связанному с древнеперсидским Вркан[35].', 'Наименование Грузии на армянском языке — «» (Врастан), в древности — «» (Вирк), означающее в переводе «Верхняя страна».']
# ...

# %% [markdown]
# #### Задача 2. ####
#
# [Колаб с интегральным морфопарсером](https://colab.research.google.com/drive/1nuIqJ-YUuDihSzi37A-YLy2uW7Ll-2Rr?usp=sharing)
#
# Возьмите любой не слишком длинный текст (можно статью). Токенизируйте его любым понравившимся токенизатором и подготовьте .conllu без разметки. Разметьте текст интегральным морфопарсером. Оцените качество.
#
# Бонус: можно сравнить лемматизацию этого парсера с mystem, например: посмотреть, сколько лемм не совпали и какие.

# %%
# Out:
# ['Эндоним', 'Грузии', '(', '«', 'Сакартвело']
